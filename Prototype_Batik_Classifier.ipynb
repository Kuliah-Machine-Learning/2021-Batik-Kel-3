# %%
import os, math
import zipfile
import numpy as np
import tensorflow as tf
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import IPython.display as display

from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **Data Set Batik**

# %%
local_zip = 'Dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()

base_dir = 'Dataset'
train_dir = os.path.join(base_dir, 'TRAIN')
validation_dir = os.path.join(base_dir, 'TEST')

BATCH_SIZE = 20
EPOCHS = 100

# %%
#TEST
# Directory with our training Batik Kawung pictures
train_kawung_dir = os.path.join(train_dir, 'Batik Kawung')

# Directory with our training Batik Megamendung pictures
train_megamendung_dir = os.path.join(train_dir, 'Batik Megamendung')

# Directory with our training Batik Parang pictures
train_parang_dir = os.path.join(train_dir, 'Batik Parang')

# Directory with our training Batik Tambal pictures
train_tambal_dir = os.path.join(train_dir, 'Batik Tambal')

#VALIDATION
# Directory with our validation Batik Kawung pictures
validation_kawung_dir = os.path.join(validation_dir, 'Batik Kawung')

# Directory with our validation Batik Megamendung pictures
validation_megamendung_dir = os.path.join(validation_dir, 'Batik Megamendung')

# Directory with our validation Batik Parang pictures
validation_parang_dir = os.path.join(validation_dir, 'Batik Parang')

# Directory with our validation Batik Tambal pictures
validation_tambal_dir = os.path.join(validation_dir, 'Batik Tambal')

# %%
# Image Generator
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=45,
      #shear_range=0.2,
      zoom_range=0.4,
      horizontal_flip=True,
      fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(200, 200),
        batch_size=BATCH_SIZE,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(200, 200),
        batch_size=BATCH_SIZE,
        class_mode='categorical')
# Out:
# Found 280 images belonging to 4 classes.
# Found 80 images belonging to 4 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(24, (3,3), input_shape=(200, 200, 3)),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation('tanh'),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2)),

    tf.keras.layers.Conv2D(32, (6,6)),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation('tanh'),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Conv2D(32, (6,6)),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation('tanh'),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (1,1)),

    tf.keras.layers.Conv2D(12, (3,3)),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation('tanh'),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),

    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(512),
    tf.keras.layers.BatchNormalization(center=True, scale=False),
    tf.keras.layers.Activation('relu'),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
              optimizer="rmsprop",
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 198, 198, 24)      672
#
#  batch_normalization_5 (Batc  (None, 198, 198, 24)     72
#  hNormalization)
#
#  activation_5 (Activation)   (None, 198, 198, 24)      0
#
#  max_pooling2d_4 (MaxPooling  (None, 99, 99, 24)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 94, 94, 32)        27680
#
#  batch_normalization_6 (Batc  (None, 94, 94, 32)       96
#  hNormalization)
#
#  activation_6 (Activation)   (None, 94, 94, 32)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 47, 47, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 47, 47, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 42, 42, 32)        36896
#
#  batch_normalization_7 (Batc  (None, 42, 42, 32)       96
#  hNormalization)
#
#  activation_7 (Activation)   (None, 42, 42, 32)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 41, 41, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 39, 39, 12)        3468
#
#  batch_normalization_8 (Batc  (None, 39, 39, 12)       36
#  hNormalization)
#
#  activation_8 (Activation)   (None, 39, 39, 12)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 19, 19, 12)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 19, 19, 12)        0
#
#  flatten_1 (Flatten)         (None, 4332)              0
#
#  dense_2 (Dense)             (None, 512)               2218496
#
#  batch_normalization_9 (Batc  (None, 512)              1536
#  hNormalization)
#
#  activation_9 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,291,100
# Trainable params: 2,289,876
# Non-trainable params: 1,224
# _________________________________________________________________

# %%
labels = train_generator.class_indices.keys()
print(labels)
# Out:
# dict_keys(['Batik Kawung', 'Batik Megamendung', 'Batik Parang', 'Batik Tambal'])

# %%
def plot_learning_rate(lr_func, epochs):
  xx = np.arange(epochs+1, dtype=np.float)
  y = [lr_decay(x) for x in xx]
  fig, ax = plt.subplots(figsize=(9, 6))
  ax.set_xlabel('epochs')
  ax.set_title('Learning rate\ndecays from {:0.3g} to {:0.3g}'.format(y[0], y[-2]))
  ax.minorticks_on()
  ax.grid(True, which='major', axis='both', linestyle='-', linewidth=1)
  ax.grid(True, which='minor', axis='both', linestyle=':', linewidth=0.5)
  ax.step(xx,y, linewidth=3, where='post')
  display.display(fig)

# %%
# lr decay function
def lr_decay(epoch):
  return 0.01 * math.pow(0.9, epoch)

# lr schedule callback
lr_decay_callback = tf.keras.callbacks.LearningRateScheduler(lr_decay, verbose=True)

# important to see what you are doing
plot_learning_rate(lr_decay, EPOCHS)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') >= 0.7):
      print("done!")
      self.model.stop_training = True

# %%
callbacks = myCallback()

history = model.fit(
      train_generator,
      steps_per_epoch=14,  # 2000 images = batch_size * steps
      epochs=EPOCHS,
      validation_data=validation_generator,
      validation_steps=4,  # 1000 images = batch_size * steps
      verbose=2,
      callbacks = [lr_decay_callback, callbacks])
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/100
# 14/14 - 6s - loss: 2.8525 - accuracy: 0.3357 - val_loss: 15.8192 - val_accuracy: 0.2500 - lr: 0.0100 - 6s/epoch - 404ms/step
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.009000000000000001.
# Epoch 2/100
# 14/14 - 3s - loss: 2.1719 - accuracy: 0.3571 - val_loss: 3.3841 - val_accuracy: 0.2500 - lr: 0.0090 - 3s/epoch - 248ms/step
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.008100000000000001.
# Epoch 3/100
# 14/14 - 3s - loss: 1.9825 - accuracy: 0.3786 - val_loss: 12.1279 - val_accuracy: 0.2750 - lr: 0.0081 - 3s/epoch - 249ms/step
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.007290000000000001.
# Epoch 4/100
# 14/14 - 3s - loss: 1.9022 - accuracy: 0.3571 - val_loss: 6.3929 - val_accuracy: 0.2750 - lr: 0.0073 - 3s/epoch - 248ms/step
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.006561.
# Epoch 5/100
# 14/14 - 3s - loss: 1.6545 - accuracy: 0.4286 - val_loss: 3.2218 - val_accuracy: 0.3375 - lr: 0.0066 - 3s/epoch - 249ms/step
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.005904900000000001.
# Epoch 6/100
# 14/14 - 4s - loss: 1.5659 - accuracy: 0.4464 - val_loss: 3.3023 - val_accuracy: 0.3500 - lr: 0.0059 - 4s/epoch - 254ms/step
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00531441.
# Epoch 7/100
# 14/14 - 3s - loss: 1.5634 - accuracy: 0.4643 - val_loss: 4.9445 - val_accuracy: 0.2875 - lr: 0.0053 - 3s/epoch - 247ms/step
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.004782969000000001.
# Epoch 8/100
# 14/14 - 3s - loss: 1.5019 - accuracy: 0.4393 - val_loss: 1.8591 - val_accuracy: 0.3125 - lr: 0.0048 - 3s/epoch - 249ms/step
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.004304672100000001.
# Epoch 9/100
# 14/14 - 3s - loss: 1.5145 - accuracy: 0.4321 - val_loss: 1.6751 - val_accuracy: 0.3625 - lr: 0.0043 - 3s/epoch - 249ms/step
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.003874204890000001.
# Epoch 10/100
# 14/14 - 4s - loss: 1.4036 - accuracy: 0.4321 - val_loss: 2.5966 - val_accuracy: 0.2750 - lr: 0.0039 - 4s/epoch - 252ms/step
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.003486784401000001.
# Epoch 11/100
# 14/14 - 3s - loss: 1.2424 - accuracy: 0.5357 - val_loss: 2.6578 - val_accuracy: 0.2375 - lr: 0.0035 - 3s/epoch - 248ms/step
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0031381059609000006.
# Epoch 12/100
# 14/14 - 4s - loss: 1.3025 - accuracy: 0.4786 - val_loss: 1.9506 - val_accuracy: 0.3875 - lr: 0.0031 - 4s/epoch - 250ms/step
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0028242953648100013.
# Epoch 13/100
# 14/14 - 4s - loss: 1.1955 - accuracy: 0.5429 - val_loss: 1.7022 - val_accuracy: 0.3375 - lr: 0.0028 - 4s/epoch - 252ms/step
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.002541865828329001.
# Epoch 14/100
# 14/14 - 3s - loss: 1.2400 - accuracy: 0.4964 - val_loss: 1.5716 - val_accuracy: 0.4125 - lr: 0.0025 - 3s/epoch - 247ms/step
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.002287679245496101.
# Epoch 15/100
# 14/14 - 3s - loss: 1.1050 - accuracy: 0.5607 - val_loss: 1.4586 - val_accuracy: 0.4250 - lr: 0.0023 - 3s/epoch - 247ms/step
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.002058911320946491.
# Epoch 16/100
# 14/14 - 3s - loss: 1.1497 - accuracy: 0.5429 - val_loss: 1.6489 - val_accuracy: 0.3500 - lr: 0.0021 - 3s/epoch - 249ms/step
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0018530201888518416.
# Epoch 17/100
# 14/14 - 3s - loss: 1.1185 - accuracy: 0.5679 - val_loss: 1.6341 - val_accuracy: 0.4125 - lr: 0.0019 - 3s/epoch - 249ms/step
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0016677181699666576.
# Epoch 18/100
# 14/14 - 3s - loss: 1.1167 - accuracy: 0.5607 - val_loss: 1.1977 - val_accuracy: 0.4875 - lr: 0.0017 - 3s/epoch - 249ms/step
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0015009463529699917.
# Epoch 19/100
# 14/14 - 3s - loss: 1.0789 - accuracy: 0.5750 - val_loss: 1.0627 - val_accuracy: 0.5750 - lr: 0.0015 - 3s/epoch - 249ms/step
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0013508517176729928.
# Epoch 20/100
# 14/14 - 3s - loss: 1.0909 - accuracy: 0.5679 - val_loss: 1.0060 - val_accuracy: 0.5750 - lr: 0.0014 - 3s/epoch - 248ms/step
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0012157665459056935.
# Epoch 21/100
# 14/14 - 3s - loss: 0.9869 - accuracy: 0.5964 - val_loss: 0.9077 - val_accuracy: 0.6250 - lr: 0.0012 - 3s/epoch - 247ms/step
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0010941898913151243.
# Epoch 22/100
# 14/14 - 3s - loss: 0.9517 - accuracy: 0.6036 - val_loss: 1.0150 - val_accuracy: 0.5875 - lr: 0.0011 - 3s/epoch - 247ms/step
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0009847709021836117.
# Epoch 23/100
# 14/14 - 3s - loss: 0.9898 - accuracy: 0.6571 - val_loss: 0.8779 - val_accuracy: 0.6625 - lr: 9.8477e-04 - 3s/epoch - 248ms/step
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0008862938119652507.
# Epoch 24/100
# 14/14 - 3s - loss: 0.9476 - accuracy: 0.6393 - val_loss: 0.8760 - val_accuracy: 0.6375 - lr: 8.8629e-04 - 3s/epoch - 247ms/step
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0007976644307687256.
# Epoch 25/100
# 14/14 - 3s - loss: 0.9874 - accuracy: 0.5750 - val_loss: 0.8808 - val_accuracy: 0.6250 - lr: 7.9766e-04 - 3s/epoch - 249ms/step
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.000717897987691853.
# Epoch 26/100
# 14/14 - 3s - loss: 0.9723 - accuracy: 0.6286 - val_loss: 0.8743 - val_accuracy: 0.5750 - lr: 7.1790e-04 - 3s/epoch - 249ms/step
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0006461081889226677.
# Epoch 27/100
# 14/14 - 3s - loss: 0.9010 - accuracy: 0.6429 - val_loss: 0.8216 - val_accuracy: 0.6500 - lr: 6.4611e-04 - 3s/epoch - 245ms/step
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.000581497370030401.
# Epoch 28/100
# 14/14 - 3s - loss: 0.9138 - accuracy: 0.6036 - val_loss: 0.8104 - val_accuracy: 0.6625 - lr: 5.8150e-04 - 3s/epoch - 248ms/step
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000523347633027361.
# Epoch 29/100
# 14/14 - 3s - loss: 0.9359 - accuracy: 0.6179 - val_loss: 0.8584 - val_accuracy: 0.6375 - lr: 5.2335e-04 - 3s/epoch - 245ms/step
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0004710128697246249.
# Epoch 30/100
# 14/14 - 4s - loss: 0.8847 - accuracy: 0.6500 - val_loss: 0.8167 - val_accuracy: 0.6500 - lr: 4.7101e-04 - 4s/epoch - 251ms/step
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0004239115827521624.
# Epoch 31/100
# 14/14 - 3s - loss: 0.8906 - accuracy: 0.6107 - val_loss: 0.7944 - val_accuracy: 0.7000 - lr: 4.2391e-04 - 3s/epoch - 245ms/step
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.00038152042447694615.
# Epoch 32/100
# 14/14 - 3s - loss: 0.9059 - accuracy: 0.6321 - val_loss: 0.8964 - val_accuracy: 0.5750 - lr: 3.8152e-04 - 3s/epoch - 248ms/step
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.00034336838202925153.
# Epoch 33/100
# 14/14 - 3s - loss: 0.9005 - accuracy: 0.6107 - val_loss: 0.7987 - val_accuracy: 0.6625 - lr: 3.4337e-04 - 3s/epoch - 247ms/step
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.00030903154382632634.
# Epoch 34/100
# 14/14 - 3s - loss: 0.9384 - accuracy: 0.6500 - val_loss: 0.8234 - val_accuracy: 0.6125 - lr: 3.0903e-04 - 3s/epoch - 247ms/step
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00027812838944369376.
# Epoch 35/100
# 14/14 - 3s - loss: 0.8848 - accuracy: 0.6357 - val_loss: 0.8027 - val_accuracy: 0.6000 - lr: 2.7813e-04 - 3s/epoch - 246ms/step
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002503155504993244.
# Epoch 36/100
# 14/14 - 3s - loss: 0.8798 - accuracy: 0.6214 - val_loss: 0.8384 - val_accuracy: 0.6375 - lr: 2.5032e-04 - 3s/epoch - 247ms/step
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.00022528399544939195.
# Epoch 37/100
# 14/14 - 3s - loss: 0.8214 - accuracy: 0.6393 - val_loss: 0.8109 - val_accuracy: 0.6500 - lr: 2.2528e-04 - 3s/epoch - 246ms/step
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.00020275559590445276.
# Epoch 38/100
# 14/14 - 3s - loss: 0.8707 - accuracy: 0.6071 - val_loss: 0.7746 - val_accuracy: 0.6750 - lr: 2.0276e-04 - 3s/epoch - 248ms/step
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001824800363140075.
# Epoch 39/100
# 14/14 - 3s - loss: 0.8447 - accuracy: 0.6429 - val_loss: 0.7765 - val_accuracy: 0.7000 - lr: 1.8248e-04 - 3s/epoch - 249ms/step
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00016423203268260675.
# Epoch 40/100
# 14/14 - 3s - loss: 0.8183 - accuracy: 0.6214 - val_loss: 0.7775 - val_accuracy: 0.6875 - lr: 1.6423e-04 - 3s/epoch - 249ms/step
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00014780882941434607.
# Epoch 41/100
# 14/14 - 3s - loss: 0.8500 - accuracy: 0.6536 - val_loss: 0.7592 - val_accuracy: 0.7125 - lr: 1.4781e-04 - 3s/epoch - 245ms/step
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00013302794647291146.
# Epoch 42/100
# 14/14 - 3s - loss: 0.8870 - accuracy: 0.6571 - val_loss: 0.7585 - val_accuracy: 0.7000 - lr: 1.3303e-04 - 3s/epoch - 245ms/step
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00011972515182562034.
# Epoch 43/100
# 14/14 - 4s - loss: 0.8199 - accuracy: 0.6464 - val_loss: 0.7523 - val_accuracy: 0.7000 - lr: 1.1973e-04 - 4s/epoch - 251ms/step
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0001077526366430583.
# Epoch 44/100
# 14/14 - 3s - loss: 0.8004 - accuracy: 0.6714 - val_loss: 0.7604 - val_accuracy: 0.6875 - lr: 1.0775e-04 - 3s/epoch - 246ms/step
#
# Epoch 00045: LearningRateScheduler setting learning rate to 9.697737297875247e-05.
# Epoch 45/100
# 14/14 - 3s - loss: 0.9013 - accuracy: 0.6250 - val_loss: 0.7577 - val_accuracy: 0.6875 - lr: 9.6977e-05 - 3s/epoch - 250ms/step
#
# Epoch 00046: LearningRateScheduler setting learning rate to 8.727963568087723e-05.
# Epoch 46/100
# 14/14 - 3s - loss: 0.8143 - accuracy: 0.6750 - val_loss: 0.7683 - val_accuracy: 0.6750 - lr: 8.7280e-05 - 3s/epoch - 250ms/step
#
# Epoch 00047: LearningRateScheduler setting learning rate to 7.855167211278951e-05.
# Epoch 47/100
# 14/14 - 4s - loss: 0.9000 - accuracy: 0.6607 - val_loss: 0.7694 - val_accuracy: 0.6875 - lr: 7.8552e-05 - 4s/epoch - 258ms/step
#
# Epoch 00048: LearningRateScheduler setting learning rate to 7.069650490151055e-05.
# Epoch 48/100
# 14/14 - 3s - loss: 0.8013 - accuracy: 0.6571 - val_loss: 0.7578 - val_accuracy: 0.6750 - lr: 7.0697e-05 - 3s/epoch - 249ms/step
#
# Epoch 00049: LearningRateScheduler setting learning rate to 6.36268544113595e-05.
# Epoch 49/100
# 14/14 - 3s - loss: 0.7927 - accuracy: 0.6643 - val_loss: 0.7557 - val_accuracy: 0.6750 - lr: 6.3627e-05 - 3s/epoch - 247ms/step
#
# Epoch 00050: LearningRateScheduler setting learning rate to 5.726416897022355e-05.
# Epoch 50/100
# 14/14 - 4s - loss: 0.8000 - accuracy: 0.6786 - val_loss: 0.7554 - val_accuracy: 0.6750 - lr: 5.7264e-05 - 4s/epoch - 251ms/step
#
# Epoch 00051: LearningRateScheduler setting learning rate to 5.15377520732012e-05.
# Epoch 51/100
# 14/14 - 3s - loss: 0.8144 - accuracy: 0.6571 - val_loss: 0.7616 - val_accuracy: 0.6750 - lr: 5.1538e-05 - 3s/epoch - 248ms/step
#
# Epoch 00052: LearningRateScheduler setting learning rate to 4.6383976865881087e-05.
# Epoch 52/100
# 14/14 - 3s - loss: 0.8368 - accuracy: 0.6429 - val_loss: 0.7706 - val_accuracy: 0.6625 - lr: 4.6384e-05 - 3s/epoch - 249ms/step
#
# Epoch 00053: LearningRateScheduler setting learning rate to 4.174557917929297e-05.
# Epoch 53/100
# 14/14 - 3s - loss: 0.8441 - accuracy: 0.6357 - val_loss: 0.7684 - val_accuracy: 0.6500 - lr: 4.1746e-05 - 3s/epoch - 248ms/step
#
# Epoch 00054: LearningRateScheduler setting learning rate to 3.757102126136367e-05.
# Epoch 54/100
# 14/14 - 3s - loss: 0.7766 - accuracy: 0.6821 - val_loss: 0.7746 - val_accuracy: 0.6375 - lr: 3.7571e-05 - 3s/epoch - 249ms/step
#
# Epoch 00055: LearningRateScheduler setting learning rate to 3.381391913522731e-05.
# Epoch 55/100
# 14/14 - 3s - loss: 0.8331 - accuracy: 0.6821 - val_loss: 0.7730 - val_accuracy: 0.6375 - lr: 3.3814e-05 - 3s/epoch - 246ms/step
#
# Epoch 00056: LearningRateScheduler setting learning rate to 3.043252722170458e-05.
# Epoch 56/100
# 14/14 - 4s - loss: 0.8035 - accuracy: 0.7000 - val_loss: 0.7721 - val_accuracy: 0.6375 - lr: 3.0433e-05 - 4s/epoch - 252ms/step
#
# Epoch 00057: LearningRateScheduler setting learning rate to 2.738927449953412e-05.
# Epoch 57/100
# 14/14 - 3s - loss: 0.8517 - accuracy: 0.6714 - val_loss: 0.7874 - val_accuracy: 0.6000 - lr: 2.7389e-05 - 3s/epoch - 245ms/step
#
# Epoch 00058: LearningRateScheduler setting learning rate to 2.4650347049580713e-05.
# Epoch 58/100
# 14/14 - 3s - loss: 0.8833 - accuracy: 0.6536 - val_loss: 0.7847 - val_accuracy: 0.6250 - lr: 2.4650e-05 - 3s/epoch - 247ms/step
#
# Epoch 00059: LearningRateScheduler setting learning rate to 2.218531234462264e-05.
# Epoch 59/100
# 14/14 - 3s - loss: 0.8185 - accuracy: 0.6643 - val_loss: 0.7762 - val_accuracy: 0.6375 - lr: 2.2185e-05 - 3s/epoch - 247ms/step
#
# Epoch 00060: LearningRateScheduler setting learning rate to 1.9966781110160377e-05.
# Epoch 60/100
# 14/14 - 3s - loss: 0.7150 - accuracy: 0.7143 - val_loss: 0.7808 - val_accuracy: 0.6250 - lr: 1.9967e-05 - 3s/epoch - 247ms/step
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1.797010299914434e-05.
# Epoch 61/100
# 14/14 - 3s - loss: 0.8359 - accuracy: 0.6607 - val_loss: 0.7756 - val_accuracy: 0.6125 - lr: 1.7970e-05 - 3s/epoch - 248ms/step
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1.6173092699229907e-05.
# Epoch 62/100
# 14/14 - 3s - loss: 0.8653 - accuracy: 0.6357 - val_loss: 0.7783 - val_accuracy: 0.6125 - lr: 1.6173e-05 - 3s/epoch - 246ms/step
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1.4555783429306915e-05.
# Epoch 63/100
# 14/14 - 3s - loss: 0.8710 - accuracy: 0.6429 - val_loss: 0.7826 - val_accuracy: 0.6125 - lr: 1.4556e-05 - 3s/epoch - 248ms/step
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1.3100205086376223e-05.
# Epoch 64/100
# 14/14 - 4s - loss: 0.7580 - accuracy: 0.6929 - val_loss: 0.7848 - val_accuracy: 0.6125 - lr: 1.3100e-05 - 4s/epoch - 254ms/step
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1.1790184577738602e-05.
# Epoch 65/100
# 14/14 - 3s - loss: 0.8274 - accuracy: 0.6500 - val_loss: 0.7882 - val_accuracy: 0.6125 - lr: 1.1790e-05 - 3s/epoch - 248ms/step
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1.061116611996474e-05.
# Epoch 66/100
# 14/14 - 3s - loss: 0.7935 - accuracy: 0.6786 - val_loss: 0.7928 - val_accuracy: 0.6000 - lr: 1.0611e-05 - 3s/epoch - 247ms/step
#
# Epoch 00067: LearningRateScheduler setting learning rate to 9.550049507968268e-06.
# Epoch 67/100
# 14/14 - 3s - loss: 0.7901 - accuracy: 0.7000 - val_loss: 0.7932 - val_accuracy: 0.5875 - lr: 9.5500e-06 - 3s/epoch - 247ms/step
#
# Epoch 00068: LearningRateScheduler setting learning rate to 8.59504455717144e-06.
# Epoch 68/100
# 14/14 - 3s - loss: 0.8245 - accuracy: 0.6964 - val_loss: 0.7929 - val_accuracy: 0.5875 - lr: 8.5950e-06 - 3s/epoch - 250ms/step
#
# Epoch 00069: LearningRateScheduler setting learning rate to 7.735540101454298e-06.
# Epoch 69/100
# 14/14 - 3s - loss: 0.7739 - accuracy: 0.7071 - val_loss: 0.7944 - val_accuracy: 0.5875 - lr: 7.7355e-06 - 3s/epoch - 248ms/step
#
# Epoch 00070: LearningRateScheduler setting learning rate to 6.961986091308868e-06.
# Epoch 70/100
# 14/14 - 3s - loss: 0.8716 - accuracy: 0.6429 - val_loss: 0.7944 - val_accuracy: 0.5875 - lr: 6.9620e-06 - 3s/epoch - 247ms/step
#
# Epoch 00071: LearningRateScheduler setting learning rate to 6.265787482177981e-06.
# Epoch 71/100
# 14/14 - 4s - loss: 0.7553 - accuracy: 0.6929 - val_loss: 0.7999 - val_accuracy: 0.6000 - lr: 6.2658e-06 - 4s/epoch - 251ms/step
#
# Epoch 00072: LearningRateScheduler setting learning rate to 5.639208733960183e-06.
# Epoch 72/100
# 14/14 - 3s - loss: 0.8092 - accuracy: 0.6500 - val_loss: 0.8007 - val_accuracy: 0.6000 - lr: 5.6392e-06 - 3s/epoch - 250ms/step
#
# Epoch 00073: LearningRateScheduler setting learning rate to 5.075287860564165e-06.
# Epoch 73/100
# 14/14 - 3s - loss: 0.8577 - accuracy: 0.6464 - val_loss: 0.7976 - val_accuracy: 0.5875 - lr: 5.0753e-06 - 3s/epoch - 248ms/step
#
# Epoch 00074: LearningRateScheduler setting learning rate to 4.567759074507749e-06.
# Epoch 74/100
# 14/14 - 3s - loss: 0.8359 - accuracy: 0.6607 - val_loss: 0.7975 - val_accuracy: 0.5875 - lr: 4.5678e-06 - 3s/epoch - 248ms/step
#
# Epoch 00075: LearningRateScheduler setting learning rate to 4.1109831670569745e-06.
# Epoch 75/100
# 14/14 - 3s - loss: 0.7678 - accuracy: 0.6821 - val_loss: 0.7977 - val_accuracy: 0.5875 - lr: 4.1110e-06 - 3s/epoch - 247ms/step
#
# Epoch 00076: LearningRateScheduler setting learning rate to 3.6998848503512767e-06.
# Epoch 76/100
# 14/14 - 3s - loss: 0.7407 - accuracy: 0.6893 - val_loss: 0.7957 - val_accuracy: 0.5875 - lr: 3.6999e-06 - 3s/epoch - 249ms/step
#
# Epoch 00077: LearningRateScheduler setting learning rate to 3.329896365316149e-06.
# Epoch 77/100
# 14/14 - 3s - loss: 0.7613 - accuracy: 0.6607 - val_loss: 0.7954 - val_accuracy: 0.5875 - lr: 3.3299e-06 - 3s/epoch - 248ms/step
#
# Epoch 00078: LearningRateScheduler setting learning rate to 2.996906728784534e-06.
# Epoch 78/100
# 14/14 - 3s - loss: 0.8235 - accuracy: 0.6571 - val_loss: 0.7951 - val_accuracy: 0.5875 - lr: 2.9969e-06 - 3s/epoch - 248ms/step
#
# Epoch 00079: LearningRateScheduler setting learning rate to 2.697216055906081e-06.
# Epoch 79/100
# 14/14 - 4s - loss: 0.8130 - accuracy: 0.6393 - val_loss: 0.7948 - val_accuracy: 0.5875 - lr: 2.6972e-06 - 4s/epoch - 250ms/step
#
# Epoch 00080: LearningRateScheduler setting learning rate to 2.427494450315473e-06.
# Epoch 80/100
# 14/14 - 4s - loss: 0.8062 - accuracy: 0.6357 - val_loss: 0.7958 - val_accuracy: 0.5875 - lr: 2.4275e-06 - 4s/epoch - 252ms/step
#
# Epoch 00081: LearningRateScheduler setting learning rate to 2.1847450052839256e-06.
# Epoch 81/100
# 14/14 - 4s - loss: 0.8254 - accuracy: 0.6536 - val_loss: 0.7958 - val_accuracy: 0.5875 - lr: 2.1847e-06 - 4s/epoch - 254ms/step
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1.9662705047555333e-06.
# Epoch 82/100
# 14/14 - 4s - loss: 0.8268 - accuracy: 0.6607 - val_loss: 0.7951 - val_accuracy: 0.6000 - lr: 1.9663e-06 - 4s/epoch - 253ms/step
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1.7696434542799798e-06.
# Epoch 83/100
# 14/14 - 4s - loss: 0.8685 - accuracy: 0.6536 - val_loss: 0.7966 - val_accuracy: 0.5875 - lr: 1.7696e-06 - 4s/epoch - 252ms/step
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1.5926791088519818e-06.
# Epoch 84/100
# 14/14 - 4s - loss: 0.7868 - accuracy: 0.6786 - val_loss: 0.7966 - val_accuracy: 0.5875 - lr: 1.5927e-06 - 4s/epoch - 252ms/step
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1.4334111979667837e-06.
# Epoch 85/100
# 14/14 - 4s - loss: 0.7806 - accuracy: 0.6750 - val_loss: 0.7980 - val_accuracy: 0.5875 - lr: 1.4334e-06 - 4s/epoch - 254ms/step
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1.2900700781701054e-06.
# Epoch 86/100
# 14/14 - 4s - loss: 0.8003 - accuracy: 0.6679 - val_loss: 0.7975 - val_accuracy: 0.5875 - lr: 1.2901e-06 - 4s/epoch - 252ms/step
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1.1610630703530949e-06.
# Epoch 87/100
# 14/14 - 4s - loss: 0.7651 - accuracy: 0.6821 - val_loss: 0.7968 - val_accuracy: 0.5875 - lr: 1.1611e-06 - 4s/epoch - 252ms/step
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1.0449567633177855e-06.
# Epoch 88/100
# 14/14 - 4s - loss: 0.8302 - accuracy: 0.6607 - val_loss: 0.7969 - val_accuracy: 0.6000 - lr: 1.0450e-06 - 4s/epoch - 251ms/step
#
# Epoch 00089: LearningRateScheduler setting learning rate to 9.404610869860068e-07.
# Epoch 89/100
# 14/14 - 4s - loss: 0.8066 - accuracy: 0.6607 - val_loss: 0.7978 - val_accuracy: 0.5875 - lr: 9.4046e-07 - 4s/epoch - 250ms/step
#
# Epoch 00090: LearningRateScheduler setting learning rate to 8.464149782874063e-07.
# Epoch 90/100
# 14/14 - 4s - loss: 0.8021 - accuracy: 0.6750 - val_loss: 0.7974 - val_accuracy: 0.5875 - lr: 8.4641e-07 - 4s/epoch - 251ms/step
#
# Epoch 00091: LearningRateScheduler setting learning rate to 7.617734804586657e-07.
# Epoch 91/100
# 14/14 - 4s - loss: 0.7821 - accuracy: 0.6964 - val_loss: 0.7975 - val_accuracy: 0.5875 - lr: 7.6177e-07 - 4s/epoch - 253ms/step
#
# Epoch 00092: LearningRateScheduler setting learning rate to 6.855961324127991e-07.
# Epoch 92/100
# 14/14 - 3s - loss: 0.8544 - accuracy: 0.6321 - val_loss: 0.7975 - val_accuracy: 0.5875 - lr: 6.8560e-07 - 3s/epoch - 250ms/step
#
# Epoch 00093: LearningRateScheduler setting learning rate to 6.170365191715192e-07.
# Epoch 93/100
# 14/14 - 3s - loss: 0.8364 - accuracy: 0.6321 - val_loss: 0.7982 - val_accuracy: 0.5875 - lr: 6.1704e-07 - 3s/epoch - 250ms/step
#
# Epoch 00094: LearningRateScheduler setting learning rate to 5.553328672543673e-07.
# Epoch 94/100
# 14/14 - 4s - loss: 0.7607 - accuracy: 0.7107 - val_loss: 0.7995 - val_accuracy: 0.5875 - lr: 5.5533e-07 - 4s/epoch - 251ms/step
#
# Epoch 00095: LearningRateScheduler setting learning rate to 4.997995805289306e-07.
# Epoch 95/100
# 14/14 - 3s - loss: 0.8302 - accuracy: 0.6464 - val_loss: 0.7983 - val_accuracy: 0.5875 - lr: 4.9980e-07 - 3s/epoch - 248ms/step
#
# Epoch 00096: LearningRateScheduler setting learning rate to 4.498196224760375e-07.
# Epoch 96/100
# 14/14 - 3s - loss: 0.8269 - accuracy: 0.6429 - val_loss: 0.7990 - val_accuracy: 0.5875 - lr: 4.4982e-07 - 3s/epoch - 250ms/step
#
# Epoch 00097: LearningRateScheduler setting learning rate to 4.048376602284338e-07.
# Epoch 97/100
# 14/14 - 4s - loss: 0.8498 - accuracy: 0.6500 - val_loss: 0.7985 - val_accuracy: 0.5875 - lr: 4.0484e-07 - 4s/epoch - 251ms/step
#
# Epoch 00098: LearningRateScheduler setting learning rate to 3.643538942055904e-07.
# Epoch 98/100
# 14/14 - 4s - loss: 0.8333 - accuracy: 0.6786 - val_loss: 0.7987 - val_accuracy: 0.5875 - lr: 3.6435e-07 - 4s/epoch - 251ms/step
#
# Epoch 00099: LearningRateScheduler setting learning rate to 3.279185047850314e-07.
# Epoch 99/100
# 14/14 - 4s - loss: 0.9447 - accuracy: 0.6036 - val_loss: 0.7994 - val_accuracy: 0.6000 - lr: 3.2792e-07 - 4s/epoch - 251ms/step
#
# Epoch 00100: LearningRateScheduler setting learning rate to 2.9512665430652826e-07.
# Epoch 100/100
# 14/14 - 4s - loss: 0.8402 - accuracy: 0.6393 - val_loss: 0.8006 - val_accuracy: 0.5875 - lr: 2.9513e-07 - 4s/epoch - 251ms/step

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy', color ='red')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss', color ='red')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(200,200))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)

  output = { 0:'kawung',1:'megamendung',2:'parang',3:'tambal'}

  print(fn)
  plt.imshow(img)
  print("Predicted :- ",output[np.argmax(classes)])
# Out:
#      <input type="file" id="files-b5df556d-fcb7-4763-96f9-cb44c3e991f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5df556d-fcb7-4763-96f9-cb44c3e991f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 89.jpg to 89.jpg
# 89.jpg
# Predicted :-  megamendung

# %%
train_kawung_fnames = os.listdir( train_kawung_dir )
train_megamendung_fnames = os.listdir( train_megamendung_dir )
train_parang_fnames = os.listdir( train_parang_dir )
train_tambal_fnames = os.listdir( train_tambal_dir )

print(train_kawung_fnames[:10])
print(train_megamendung_fnames[:10])
print(train_parang_fnames[:10])
print(train_tambal_fnames[:10])
# Out:
# ['25.jpg', '52.jpg', '64.jpg', '33.jpg', '44.jpg', '20.jpg', '15.jpg', '21.jpg', '50.jpg', '35.jpg']
# ['25.jpg', '52.jpg', '64.jpg', '33.jpg', '44.jpg', '20.jpg', '15.jpg', '21.jpg', '50.jpg', '35.jpg']
# ['25.jpg', '52.jpg', '64.jpg', '33.jpg', '44.jpg', '20.jpg', '15.jpg', '21.jpg', '50.jpg', '35.jpg']
# ['25.jpg', '52.jpg', '64.jpg', '33.jpg', '44.jpg', '20.jpg', '15.jpg', '21.jpg', '50.jpg', '35.jpg']

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Let's prepare a random input image of a cat or dog from the training set.
kawung_img_files = [os.path.join(train_kawung_dir, f) for f in train_kawung_fnames]
megamendung_img_files = [os.path.join(train_megamendung_dir, f) for f in train_megamendung_fnames]
parang_img_files = [os.path.join(train_parang_dir, f) for f in train_parang_fnames]
tambal_img_files = [os.path.join(train_tambal_dir, f) for f in train_tambal_fnames]

img_path = random.choice(kawung_img_files + megamendung_img_files + parang_img_files + tambal_img_files)
img = load_img(img_path, target_size=(200, 200))  # this is a PIL image

x   = img_to_array(img)                           # Numpy array with shape (150, 150, 3)
x   = x.reshape((1,) + x.shape)                   # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255.0

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# Now let's display our representations
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )

# %%
# !pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in /usr/local/lib/python3.7/dist-packages (3.12.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.7.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.22.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.10.0.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (12.0.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.42.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.13.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)

# %%
import pathlib

# %%
saved_model_path = "./my_model.h5"

model.save("./model/batik_classifier.h5")

# !tensorflowjs_converter --input_format=keras {"./model/batik_classifier.h5"} ./batik_classifier/

tf.saved_model.save(model, "./model/1")
converter = tf.lite.TFLiteConverter.from_saved_model("./model/1")
tflite_model = converter.convert()
tflite_model_file = pathlib.Path('./model/batik_classifier.tflite')
tflite_model_file.write_bytes(tflite_model)

# !zip -r ./batik_classifier.zip ./model/
# Out:
# INFO:tensorflow:Assets written to: ./model/1/assets
# INFO:tensorflow:Assets written to: ./model/1/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# updating: model/ (stored 0%)
# updating: model/batik_classifier.h5 (deflated 9%)
# updating: model/batik_classifier.tflite (deflated 7%)
# updating: model/1/ (stored 0%)
# updating: model/1/saved_model.pb (deflated 90%)
# updating: model/1/assets/ (stored 0%)
# updating: model/1/variables/ (stored 0%)
# updating: model/1/variables/variables.index (deflated 70%)
# updating: model/1/variables/variables.data-00000-of-00001 (deflated 8%)

# %%
from google.colab import files

files.download("./batik_classifier.zip")
